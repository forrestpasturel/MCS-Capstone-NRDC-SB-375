# %% [markdown]
# # The Diagnostic: Identifying the Failure
#
# This notebook covers Part 1 of the capstone analysis:
# 1. Loading VMTIndex at Census Block Group level.
# 2. Loading CalEnviroScreen 4.0 data.
# 3. Joining and visualizing where VMT trends and pollution burdens overlap specifically targeted toward justifying "Corrective Action" criteria.

# %%
import pandas as pd
import geopandas as gpd
import plotly.express as px

from src.data_access.loaders import load_vmtindex, load_calenviro
from src.analysis.metrics import join_vmt_env
