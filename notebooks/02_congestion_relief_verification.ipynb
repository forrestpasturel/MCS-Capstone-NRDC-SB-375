# %% [markdown]
# # The Verification: Debunking Congestion Relief
#
# This notebook covers Part 2, demonstrating induced demand for a recently widened highway segment (e.g., I-80 in Yolo County).
#
# 1. Read Caltrans PeMS detector data pre- and post-widening.
# 2. Compare speeds to show reversion to congested levels.
# 3. Estimate induced VMT CO2 penalty using the NCST Induced Travel Calculator logic.

# %%
import pandas as pd
import plotly.express as px

from src.data_access.loaders import load_pems
from src.analysis.metrics import compute_congestion_metrics, estimate_induced_vmt_from_ncst
