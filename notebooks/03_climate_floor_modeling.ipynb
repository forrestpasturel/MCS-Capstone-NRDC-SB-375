# %% [markdown]
# # The Vision: Modeling the Climate Floor
#
# This part models Scenario A (capacity expansion) vs Scenario B (multimodal/infill) for a corridor to calculate standard GHG differences using EMFAC, setting up a "Climate Floor" requirement (objective measurement).

# %%
import pandas as pd
import plotly.express as px

from src.data_access.loaders import load_tdm_scenario, load_emfac_results
from src.analysis.metrics import compute_climate_floor_score
